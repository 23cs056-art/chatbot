# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install gunicorn/
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'gunicorn/'
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install gunicorn
# Out:
# ...
#    ---------------------------------------- 0.0/208.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/208.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/208.4 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/208.4 kB 435.7 kB/s eta 0:00:01
#    --------------------------- ------------ 143.4/208.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 208.4/208.4 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
